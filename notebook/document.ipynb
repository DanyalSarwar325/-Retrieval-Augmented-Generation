# %% [markdown]
# ### Data Ingestion

# %%
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="This is a test document.",
    metadata={
        "source": "test.txt",
        "author":"Danyal",
        "pages":1
        }

)

# %%
doc
# Out:
# Document(metadata={'source': 'test.txt', 'author': 'Danyal', 'pages': 1}, page_content='This is a test document.')

# %%
#create simple text file
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_text ={
"../data/text_files/sample.txt":"""Introduction
This is a sample text file for testing the Document class in LangChain.
It contains multiple lines of text to demonstrate how the Document class can handle larger content.     
The Document class is useful for representing text data along with its associated metadata, such as the source, author, and number of pages.
"""

}

# %%
for file_path, content in sample_text.items():
    with open(file_path, "w", encoding="utf-8") as f:
        f.write(content)
print("Sample text file created successfully.")
# Out:
# Sample text file created successfully.

# %%
#Text Loader
from langchain_community.document_loaders import TextLoader

# %%
loader=TextLoader("../data/text_files/sample.txt")

# %%
documents=loader.load()

# %%
print(documents)
# Out:
# [Document(metadata={'source': '../data/text_files/sample.txt'}, page_content='Introduction\nThis is a sample text file for testing the Document class in LangChain.\nIt contains multiple lines of text to demonstrate how the Document class can handle larger content.     \nThe Document class is useful for representing text data along with its associated metadata, such as the source, author, and number of pages.\n')]

# %%
## Directory Loader
from langchain_community.document_loaders import DirectoryLoader

directory_loader=DirectoryLoader("../data/text_files",
                                  glob="*.txt",
                                  loader_cls=TextLoader,
                                  loader_kwargs={"encoding": "utf-8"})

# %%
directory_loader

# %%
print(directory_loader.load())
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\sample.txt'}, page_content='Introduction\nThis is a sample text file for testing the Document class in LangChain.\nIt contains multiple lines of text to demonstrate how the Document class can handle larger content.     \nThe Document class is useful for representing text data along with its associated metadata, such as the source, author, and number of pages.\n')]

# %%
#for Pdf Loader
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader
pdf_loader=DirectoryLoader("../data/pdf",
                                  glob="*.pdf",
                                  loader_cls=PyMuPDFLoader,
                                  
                                  show_progress=False
                                  )

# %%
pdf=pdf_loader.load()

# %%
pdf
# Out:
# [Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 0}, page_content='1\nBack-End Development\nWeb Servers,\nBack-end Abstractions,\nBuilding APIs\n1'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 1}, page_content='Lec 10: Web Servers\n2'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 2}, page_content='What is a web server?\nA web server is both a type of software and a piece of hardware \nthat stores, processes, and delivers web pages to users over the \ninternet.\nSteps:\n• User types an address "www.example.com," or click a link\n• Computer (called the "client") sends a request to the web server\n• Server then sends the right information back to the client.\n•\nA web server is both a type of software and a piece of hardware that stores, \nprocesses, and delivers web pages to users over the internet. When you type in a \nwebsite address, like "www.example.com," or click a link, your computer (called \nthe "client") sends a request to the web server, which then sends the right \ninformation back to your computer.\n•\nThink of a web server as a waiter in a restaurant:\n•\nWhen you, the customer, ask for a dish (like clicking a link), the waiter (the web \nserver) takes your order, goes to the kitchen, and brings you your food (in this \ncase, the web page).\n•\nThe main job of the server is to listen, understand, and respond to requests from \nclients (like a browser on your phone or computer).\n3'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 3}, page_content='Relatable Example\n• Think of a web server as a waiter in a restaurant:\n• When you, the customer, ask for a dish (like clicking a link), the \nwaiter (the web server) takes your order, goes to the kitchen, and \nbrings you your food (in this case, the web page).\n• The main job of the server is to listen, understand, and respond to \nrequests from clients (like a browser on your phone or computer).\n4'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 4}, page_content='Components of a Web Server\nSoftware\nHardware\nProtocols\nUses HTTP to handle users’ requests and responses on a \nwebsite.\nConsists of physical components that store the website’s \nfiles and documents, and the web server’s software; \nenables communication through internet to share files\nFacilitate intercommunication between web servers and \ncomputers. Examples are: HTTPS for static content \ndelivery such as images and documents; SMTP for mail \ndelivery; and FTP for file transfer and storage.\nA web server’s software component uses HTTP to handle users’ requests and \nresponses on a website.\nThe hardware consists of computers that store website files and documents and the \nweb server’s software; such files include HTML, CSS, and JavaScript files. The hardware \nenables internet communication to share these files. Examples of web server hardware \ninclude CPU, RAM, GPU, and SSDs.\nProtocols facilitate intercommunication between web servers and computers. They \ninclude HTTPS, which helps in static content delivery such as images and documents; \nSMTP, which allows mail delivery; and FTP, which helps in file transfer and storage.\n5'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 5}, page_content='Web Server -Hardware\nA computer (“server”) connected to the internet (or any network) \n[Physical Entity]\nProperties of contemporary web servers\n• Part of large datacenters\n• Latency is geographically dependent, so web servers are often \ngeographically distributed (works through, e.g., DNS)\n• Virtual servers: Physical servers can host many virtualized (web) \nservers\nCan also be your own computer (localhost) \n6'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 6}, page_content='Key Concepts- Revision\n• Requests and Responses: Every time you type a URL or click on a link, \nyour browser sends a request to the web server. The server then \nresponds with the webpage or file you wanted.\n• HTTP Protocol: Web servers and clients communicate through the \nHTTP protocol, which stands for Hypertext Transfer Protocol. This \nprotocol tells the web server how to handle and deliver the files \nrequested.\n• Serving Content: Web servers deliver different types of files, like:\n• HTML files (the code for web pages),\n• Images (like PNG, JPG),\n• Styles (CSS), and\n• Scripts (JavaScript files).\n7'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 7}, page_content='Various web servers with numerous software solutions are available to meet the \ndiverse needs of websites and web applications. The following are common examples.\nApache HTTP server\nApache HTTP Server is an open-source software built for operating systems like \nWindows, UNIX, and Mac OS. It provides secure and standard web server software for \nwebsites.\nAs a versatile web server software, Apache’s architecture provides a customizable \nfunctionality that creates a wide range of features. Among other web servers, Apache \nhas about 20.7 percent of the market. Due to its popularity, it’s the go-to web server \nfor developers, web owners, and hosting service providers.\nNGINX\nNGINX is another popular web server that manages 23.21 percent of all websites. It‘s \nwidely used for caching, load balancing, media streaming, etc. NGINX offers low \nmemory consumption and a high asynchronous mode of serving web requests.\nInternet information services (IIS)\nMicrosoft developed and maintained the IIS web server. It provides a secure website \nlayer with a low surface area and maximum functionality.\nSun Java system\nThis multithreaded web server software provides high performance and scalability to \n8'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 8}, page_content='websites. It operates multiple single-threaded child processes simultaneously and \ndistributes all incoming requests among the child processes for better performance.\nJigsaw server, implemented on the JAVA programming language, is an open-source \nweb server software with a modular architecture. It uses an object-oriented approach \nto store files and process requests. Sun Java manages about 0.1 percent of all \nwebsites.\nApache Tomcat\nApache Tomcat is an open-source Java Server Page container and Java servlet used to \nhost and run Java applications and websites. It helps Java apps with dynamic content \nfor multiple requests. It’s an intermediary between the web server and the Java \napplication to ensure efficient and secure data access.\nRegardless of the chosen web server software, its architecture is crucial in determining \nits performance and scalability.\n8'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 9}, page_content='Server Side Code\n• Server side code could be simply a file that the server passes back \nto the client, which is then displayed for the user\n \n \n \n \nOR \n• Could be a program, written in PHP, Perl, Ruby, Python, C, or some \nother language that performs an operation and sends results back \nto the client browser.  \n9'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 10}, page_content='How Web Servers Work?\n10'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 11}, page_content='11'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 12}, page_content='Client-Server Relationship\n• Client: This is usually a web browser, like Chrome, Firefox, or \nSafari. The client asks for information from the web server.\n• Server: This is the machine that holds the data or files the client \nwants. When a client makes a request, the server responds.\n• For example, "www.example.com":\n• The browser sends a request to the server where "example.com" \nis hosted.\n• The server receives this request, finds the right file (like an HTML \npage), and sends it back.\n• The browser then displays the page.\n12'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 13}, page_content='The Request-Response Cycle\n• Every time you visit a webpage, your browser and the web server go \nthrough something called the request-response cycle. Here’s what \nhappens:\n• Request: The browser sends a request for the webpage. This request is \ntypically a URL, which points to a particular resource (like an HTML file) \non the server.\n• Processing: The web server reads the request and decides how to \nrespond. It finds the necessary files or scripts needed to fulfill the \nrequest.\n• Response: The server sends back the requested data (HTML, images, \nor other files) to the client.\n• Rendering: The client (browser) receives the data and renders \n(displays) the webpage.\n13'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 14}, page_content='Key-Components\n• HTTP Protocol: The primary protocol that governs how the web server and \nthe client communicate. It includes requests like GET (to fetch data) and \nPOST (to send data).\n• TCP/IP Stack: This is the foundation of data transfer over the internet. It’s \nresponsible for ensuring that the data packets between the client and server \nare transmitted accurately.\n• Real-life Example\n• Think of visiting a library:\n• You (the client) ask the librarian (the web server) for a book.\n• The librarian finds the book and hands it to you.\n• In the same way, the client requests data, and the server locates it and \ndelivers it back to the client.\n14'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 15}, page_content='15'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 16}, page_content='Secure servers\nSeamless transfer of data\nVarious hosting options\nHigh Uptime\nFlexibility\nWebsite performance\nRanking\nFunctions of a Web Server\nHigh uptime\nA web server’s primary function is to provide a standby hardware infrastructure to \nstore websites and maintain high uptime so that users can access hosted websites and \nweb applications.\nSeamless transfer of data\nA web server provides an adequate and safe delivery of online content.\nSecure servers\nWeb server hosts can provide robust security protocols and reduce cyber attacks, \nincluding Secure Sockets Layer (SSL),Secure Sockets Shell (SSH), and reverse proxy.\nVarious hosting options\nWeb servers provide different hosting options to accommodate diverse needs and \nrequirements. These options include shared hosting, VPS hosting (virtual private \nservers), dedicated servers, and cloud hosting, each with features and resources.\nFlexibility\nWeb servers offer high flexibility and support for programming languages, databases, \nand frameworks. This flexibility allows developers to choose the technologies that best \nsuit their project requirements.\nWebsite performance\nWeb servers enhance a website’s performance by clearing the storage cache of files \n16'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 17}, page_content='that have no use. Caches take up space on a web server and slow down a website. \nClearing the cache provides more storage space for other valuable files and \ndocuments.\nRanking\nWeb servers improve website ranking by optimizing page load and server response \ntimes. Faster page speeds and server response times contribute to better user \nexperiences, a significant ranking factor for search engines like Google.\n16'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 18}, page_content='Types of Web Servers\nWeb servers can be categorized based on how they work and what they’re capable of \ndelivering. We wil ldiscuss two main types:\n17'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 19}, page_content='Static Servers\n• A static web server delivers content that doesn’t change. \n• A web page that’s a simple HTML file with text and images. It looks \nthe same for every visitor, and the server doesn’t have to do any \nextra processing to serve it.\n• Characteristics of Static Servers:\n• Serves fixed content (no customization).\n• Often faster, as no processing is needed.\n• Simple setup; just serves files from the server.\n• Example: A website with a collection of images. The server just \nserves these images without doing any additional work. The server \nalways delivers the same files in the same way.\n18'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 20}, page_content='Dynamic Servers\n• A dynamic web server can create pages based on information in \nreal-time. For example, on a social media site, the pages change \nbased on who’s logged in. The server might pull your friends list \nfrom a database and show you a personalized homepage.\n• Characteristics of Dynamic Servers:\n• Uses software to process data and deliver custom content.\n• Can connect to a database to fetch and display information based on \nuser input.\n• Requires extra software, like PHP, Python, or Node.js, to handle requests \ndynamically.\n• Example: An e-commerce website. When you log in, it shows you \nitems you’ve browsed or recommended products. The server pulls \nthis information from a database and creates a page just for you.\n19'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 21}, page_content="Popular Web Servers\n• Apache HTTP Server: The most widely used web server globally, \nknown for its flexibility and open-source nature. Often used in \ncombination with PHP for dynamic websites.\n• NGINX: Another popular server, known for handling a lot of users \nat once. It’s great for high-traffic websites. Often used as a load \nbalancer and reverse proxy.\n• Microsoft IIS (Internet Information Services): A web server \ndeveloped by Microsoft, mainly for Windows-based applications.\n• Each of these has its strengths, but they all serve the same basic \npurpose: delivering content to clients quickly and reliably.\n1. Apache HTTP Server (Apache)\nWhat is Apache?\nApache HTTP Server, commonly referred to simply as Apache, is one of the oldest \nand most widely used open-source web servers. Apache was developed by the \nApache Software Foundation and has been in use since 1995. It is known for its \nflexibility, configurability, and ability to run on various operating systems like Linux, \nUnix, macOS, and Windows.\nKey Features:\n•Modular Architecture: Apache allows the addition of various modules (e.g., \nmod_php for PHP, mod_ssl for SSL support, mod_rewrite for URL rewriting). This \nmakes Apache extremely versatile.\n•Dynamic Content: Apache is particularly strong at handling dynamic content using \nserver-side scripting modules (e.g., mod_php for PHP, mod_python for Python).\n•.htaccess Files: Apache can use .htaccess files to configure settings at the directory \nlevel, which is especially useful for shared hosting environments.\n•Flexibility: Apache is flexible and configurable, which is why it's often used for a \nwide variety of web applications and websites.\nUse Cases:\n•Hosting websites with dynamic content (e.g., WordPress, LAMP stack).\n20"),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 22}, page_content='•Shared hosting environments, where .htaccess and per-directory configuration are \nimportant.\n•Websites that require deep customization of server behavior through configuration \nfiles.\nPlatform Support:\n•Cross-platform (Linux, Unix, macOS, Windows).\nPerformance:\n•Apache tends to use more memory and CPU under heavy load due to its \nprocess/thread-based architecture. However, it can be optimized with different multi-\nprocessing modules like mpm_event or mpm_worker.\n2. Nginx\nWhat is Nginx?\nNginx (pronounced "engine-x") is an open-source, high-performance web server \ndesigned for speed and scalability. It was originally built to handle high concurrency \nand low resource usage, and it has quickly gained popularity, particularly for modern \nweb applications.\nKey Features:\n•Event-Driven, Asynchronous Model: Nginx uses an event-driven model to handle \nincoming requests. It can process many requests at once without the need for \ncreating new threads or processes for each request, making it more efficient than \nApache under high traffic.\n•Reverse Proxy and Load Balancing: Nginx is commonly used as a reverse proxy \nserver and load balancer in front of application servers, distributing traffic across \nmultiple backend servers.\n•Static Content: Nginx is optimized for serving static content quickly and with low \nmemory usage. This makes it ideal for serving static files like HTML, CSS, JavaScript, \nimages, and videos.\n•SSL Termination: Nginx is often used to handle SSL/TLS encryption (SSL termination) \nefficiently.\nUse Cases:\n•Reverse Proxy Server: Commonly used to reverse proxy traffic to backend servers \n(e.g., Node.js, PHP-FPM, or application servers).\n•Static Content Serving: Great for serving static content, which is why it\'s used in \nmany high-traffic environments.\n•High-Concurrency Environments: Nginx is optimized for environments where \nhandling many concurrent connections is necessary (e.g., media streaming, content-\nheavy websites).\nPlatform Support:\n•Cross-platform (Linux, Unix, macOS, Windows). However, it\'s most commonly used \non Linux-based systems.\nPerformance:\n•Very fast and efficient, particularly for static content and reverse proxy use cases. \n20'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 23}, page_content="Due to its asynchronous, event-driven model, Nginx is highly scalable and handles \nmany concurrent requests with minimal memory and CPU usage.\n3. Microsoft IIS (Internet Information Services)\nWhat is IIS?\nMicrosoft IIS (Internet Information Services) is a proprietary web server developed \nby Microsoft for Windows Server operating systems. It is closely integrated with the \nWindows ecosystem, making it a popular choice for enterprises that use Microsoft \ntechnologies.\nKey Features:\n•Integrated with Windows: IIS is tightly integrated into the Windows Server \nenvironment, making it a natural choice for organizations that use other Microsoft \nproducts (e.g., .NET applications, Windows authentication, SQL Server).\n•GUI Management Interface: IIS provides a user-friendly graphical user interface \n(GUI) for configuration and management, making it easier for non-technical users to \nadminister the server.\n•Security Features: IIS has strong security features, including request filtering, URL \nauthorization, and support for Windows Authentication and Active Directory \nintegration.\n•Support for .NET: IIS is optimized for serving ASP.NET applications and integrates \nwell with the Microsoft stack (e.g., SQL Server, Active Directory).\nUse Cases:\n•ASP.NET Web Applications: IIS is the go-to web server for serving ASP.NET \napplications (MVC, Web API, etc.).\n•Microsoft Ecosystem: If your environment is heavily tied to Microsoft technologies \nlike Windows Server, SQL Server, or Active Directory, IIS is a natural choice.\n•Enterprise Environments: IIS is often chosen by large organizations due to its \nintegration with Windows, security features, and GUI management.\nPlatform Support:\n•Windows only (Windows Server and Windows OS).\nPerformance:\n•IIS is quite efficient in a Windows environment, especially for Microsoft-based \napplications. However, it's not as efficient as Nginx for serving static content or as \nflexible as Apache for handling dynamic content across multiple platforms.\n20"),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 24}, page_content="Apache vs Nginx\n• Apache is best suited for dynamic content serving and provides a \nhighly customizable environment with powerful modules for various \nback-end technologies.\n• Nginx excels at handling high-traffic environments where static \ncontent and load balancing are essential. It is known for its efficiency \nand low resource usage, making it ideal for serving static files and as a \nreverse proxy.\n• In real-world deployments, many organizations use both Apache and \nNginx together\n• Nginx acts as a reverse proxy in front of Apache (or other backend \nservers) to handle incoming requests, serve static content, and \ndistribute the load, while Apache is used for handling dynamic content. \nThis is a common setup for high-performance websites and \napplications.\nApache and Nginx are two of the most popular web servers used to serve web \ncontent (like websites, web applications, and APIs) over the internet. They each have \ntheir own unique features, benefits, and trade-offs. Let's explore each of them in \ndetail:\n1. Apache HTTP Server (Apache)\nWhat is Apache?\nApache, or Apache HTTP Server, is one of the oldest and most widely used web \nservers. It's open-source software developed by the Apache Software Foundation. \nApache serves web content, handles HTTP requests, and can serve static content (like \nHTML, CSS, JavaScript, images) and dynamic content (like PHP, Python, etc.) using \ndifferent modules.\nKey Features of Apache:\n•Modular Architecture: Apache is highly modular, meaning you can extend its \nfunctionality with various modules (e.g., mod_php for PHP, mod_ssl for SSL/TLS \nsupport).\n•Dynamic Content Handling: Apache is great for serving dynamic content using \nmodules like mod_php (for PHP), mod_python, mod_wsgi, etc. This makes it ideal for \nwebsites and applications that require server-side scripting.\n•.htaccess Files: Apache allows for per-directory configuration using .htaccess files, \n21"),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 25}, page_content='which enable fine-grained control over settings on a directory or file basis (e.g., \nredirects, security settings, URL rewrites).\n•Multi-threaded: Apache uses a multi-threaded or multi-process model depending \non its configuration, meaning it can handle multiple requests at the same time.\nUse Cases of Apache:\n•Websites and applications requiring dynamic content generation.\n•LAMP stack (Linux, Apache, MySQL, PHP) applications, especially for legacy \napplications.\n•Hosting on shared servers where customization per directory is needed using \n.htaccess.\nDrawbacks of Apache:\n•Performance: Apache is often slower than Nginx, especially under high traffic loads, \nbecause it creates a new thread or process for each request (though this can be \nmitigated with optimizations).\n•Memory Usage: Apache can be more memory-intensive due to its process-based \nmodel.\n2. Nginx\nWhat is Nginx?\nNginx (pronounced "engine-x") is an open-source web server and reverse proxy \nserver that is designed to be high-performance, highly scalable, and efficient. It was \noriginally created by Igor Sysoev in 2004 and has become widely popular due to its \nability to handle large amounts of concurrent traffic with minimal resource \nconsumption.\nNginx is commonly used as a reverse proxy server, meaning it forwards client \nrequests to other servers (like application servers or databases), but it can also be \nused to serve static content.\nKey Features of Nginx:\n•Event-driven Architecture: Nginx uses an event-driven, asynchronous model. This \nallows it to handle many requests simultaneously with a small amount of memory \nand without spawning new threads or processes. This makes Nginx much more \nscalable and efficient than Apache.\n•Reverse Proxying: Nginx is often used as a reverse proxy server to balance the load \nbetween multiple application servers. It efficiently routes incoming requests to the \nappropriate backend servers and can distribute the traffic.\n•Handling Static Content: Nginx is known for its superb handling of static content. It \nis faster than Apache when serving static files like HTML, CSS, JavaScript, images, and \nvideos due to its low overhead.\n•SSL/TLS Termination: Nginx can offload SSL/TLS processing (SSL termination), \nreducing the burden on backend servers.\n•High Performance & Low Resource Usage: Nginx is highly efficient and uses far \nfewer resources (memory and CPU) when handling large numbers of requests \ncompared to Apache.\n21'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 26}, page_content="Use Cases of Nginx:\n•Reverse Proxy and Load Balancing: Nginx is widely used in production environments \nas a reverse proxy and load balancer for distributing traffic across multiple servers.\n•Serving Static Content: Nginx is ideal for serving static files like HTML, CSS, images, \netc.\n•Scaling Web Applications: It's often used as a gateway server in front of application \nservers (e.g., Node.js, PHP-FPM) for better performance and handling high traffic.\nDrawbacks of Nginx:\n•Dynamic Content Handling: While Nginx can handle dynamic content via integration \nwith other backends (e.g., FastCGI, PHP-FPM, or application servers), it's not as native \nas Apache's integration with dynamic content. This can be a drawback if you're \nheavily using server-side scripting.\n•Configuration Complexity: Nginx configuration can sometimes be harder for \nbeginners to understand, especially in terms of advanced features like load balancing \nor reverse proxying.\n21"),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 27}, page_content='22'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 28}, page_content='23'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 29}, page_content='Virtual Servers and Containers\nOne physical \nserver can host \nmultiple virtual \nservers and/or \ncontainers\n24'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 30}, page_content='Web Server Architecture\n25'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 31}, page_content='Introduction to Web Server Architecture\n• Web server architecture is the structure of a web server that \nallows it to handle multiple tasks efficiently. This involves:\n• How requests are managed,\n• How the server resources are used, and\n• How different parts of the server interact to handle large \nnumbers of client requests without slowing down.\n• Web server architecture can be single-process (handling \nrequests one at a time) or multi-process (handling multiple \nrequests at the same time).\nThe web server architecture represents a web server’s layout, structure, and \ncomponents. It outlines the working system of a functional web server. This includes \nhow the server handles incoming server requests and delivers responses to the client’s \ncomputers.\nThere are two main approaches to web server architecture:\n•Concurrent approach.\n•Single-process-event-driven approach.\n26'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 32}, page_content='Single-Tier Architecture\n• Also called single server architecture\n• A single server is responsible for both processing requests and serving web \ncontent\n• The web server processes only one request at a time.\n• Only suitable for low-traffic / small websites\n• Limitations in terms of scalability and fault tolerance. \n• If the server goes down, the entire service becomes unavailable.\n• Example: If one person is viewing a page, another person has to wait until \nthe first person’s request is completed before the server can process theirs.\n27'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 33}, page_content='Multi-Tier Architecture\n•Also called Load-Balanced Architecture\n•Multiple servers are used to distribute the workload and ensure high \navailability.\n•Each request is managed by a different “process” or “thread,” which helps \nspeed things up and ensures that users don’t have to wait as long.\n•This approach often involves load balancers that evenly distribute incoming \nrequests across a cluster of web servers. \n•Each server can serve web content independently, and if one server fails, the \nload balancer redirects traffic to healthy servers, ensuring uninterrupted \nservice.\n•Most modern web servers, like Apache and NGINX, use multi-process \narchitecture to handle high traffic.\n1. Multi-process\nA multi-process approach starts with a base process. It creates different single-\nthreaded branch processes. These branches divide the requests among them. Once \ndone, each branch handles a single request without affecting the other. This threading \nhandles all requests without depending on other requests.\n2. Multi-threaded\nA server manages many client requests at once using multiple threads. The server \ngenerates a thread to interact with every client’s request for other users \nsimultaneously, making it more efficient for the server to respond quickly to many \nclient requests.\n3. Hybrid\nThe hybrid method is a combination of both multi-process and multi-threaded \nmethods where multiple processes are created. These multiple processes create \nthreads that handle single requests at a time.\n28'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 34}, page_content='Load Balancing\n• When multiple servers are used to spread out or balance the \nincoming requests so no single server gets overwhelmed.\n• Why Use Load Balancing? When websites have many visitors, a \nsingle server can become overloaded. Load balancers distribute \nthe requests to multiple servers, ensuring a smoother experience \nfor users.\n• How It Works: A load balancer sits between the client and the \nweb servers. When a client requests a page, the load balancer \ndirects it to the server with the least load.\n29'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 35}, page_content='30'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 36}, page_content='31'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 37}, page_content='Reverse Proxy\n• A reverse proxy is a type of server that sits in front of web \nservers and directs client requests to the appropriate \nbackend server. It provides an extra layer of security and \nhelps in load balancing as well.\n• Benefits:\n• Security: Protects the identity and location of the backend server.\n• Efficiency: Redirects requests to different servers based on load.\n• Example: NGINX can act as a reverse proxy. If a site has \nmultiple servers, NGINX can manage which server a client is \ndirected to.\n32'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-04T00:34:22+05:00', 'source': '..\\data\\pdf\\Lecture 10.pdf', 'file_path': '..\\data\\pdf\\Lecture 10.pdf', 'total_pages': 75, 'format': 'PDF 1.7', 'title': '', 'author': 'DELL', 'subject': '', 'keywords': '', 'moddate': '2024-12-04T00:34:22+05:00', 'trapped': '', 'modDate': "D:20241204003422+05'00'", 'creationDate': "D:20241204003422+05'00'", 'page': 38}, page_content='33'),
# ...
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-10T18:00:58+05:00', 'source': '..\\data\\pdf\\Lecture 12.pdf', 'file_path': '..\\data\\pdf\\Lecture 12.pdf', 'total_pages': 55, 'format': 'PDF 1.7', 'title': '', 'author': 'Nida Rasheed', 'subject': '', 'keywords': '', 'moddate': '2024-12-10T18:00:58+05:00', 'trapped': '', 'modDate': "D:20241210180058+05'00'", 'creationDate': "D:20241210180058+05'00'", 'page': 42}, page_content='import React, { useEffect, useState } from \'react\';\nfunction App() {\n  const [message, setMessage] = useState(\'\');\n  // Fetch message from the backend API\n  useEffect(() => {\n    fetch(\'http://localhost:5000/api/message\')\n      .then(response => response.json())\n      .then(data => setMessage(data.message));\n  }, []);\n  return (\n    <div className="App">\n      <h1>{message}</h1>\n    </div>\n  );\n}\nexport default App;\nThis React app fetches data from the Node.js backend and displays it.\nimport React, { useEffect, useState }: This line imports the necessary hooks \n(useState, useEffect) from React. useState is used to manage the state of \nvariables in the component, and useEffect allows you to perform side effects, \nlike fetching data from an API.\nfunction App(): This is the main component function for your React app. Inside \nthis function, you define the component\'s behavior and structure.\nconst [message, setMessage] = useState(\'\');: Here, the message state is \ninitialized with an empty string. The setMessage function will be used to update \nthe message state when data is fetched from the backend.\nuseEffect(() => { ... }, []): This is a hook that runs after the component has \nmounted (i.e., rendered for the first time). The empty dependency array [] \nensures the effect runs only once when the component is initially loaded.\nfetch(\'http://localhost:5000/api/message\'): This makes a fetch request to the \n40'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-10T18:00:58+05:00', 'source': '..\\data\\pdf\\Lecture 12.pdf', 'file_path': '..\\data\\pdf\\Lecture 12.pdf', 'total_pages': 55, 'format': 'PDF 1.7', 'title': '', 'author': 'Nida Rasheed', 'subject': '', 'keywords': '', 'moddate': '2024-12-10T18:00:58+05:00', 'trapped': '', 'modDate': "D:20241210180058+05'00'", 'creationDate': "D:20241210180058+05'00'", 'page': 43}, page_content='backend server at http://localhost:5000/api/message. The fetch request will get \nthe data from the Express API you defined earlier.\n.then(response => response.json()): After receiving the response, the .json() \nmethod is used to parse the JSON data sent by the backend.\n.then(data => setMessage(data.message)): Once the data is fetched, we \nupdate the message state with the value received from the backend \n(data.message).\nreturn (...): The component returns JSX, which defines the structure of the \nfrontend UI. The content of the h1 tag is dynamically populated with the message \nstate.\n<h1>{message}</h1>: This will display the message received from the backend \nAPI. Initially, it will be empty (\'\'), but after the data is fetched from the backend, it \nwill show "Hello from the backend!" as defined in the Express server.\nexport default App;: This exports the App component as the default export, \nmaking it available to other parts of the application (e.g., for rendering in \nindex.js).\n40'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-10T18:00:58+05:00', 'source': '..\\data\\pdf\\Lecture 12.pdf', 'file_path': '..\\data\\pdf\\Lecture 12.pdf', 'total_pages': 55, 'format': 'PDF 1.7', 'title': '', 'author': 'Nida Rasheed', 'subject': '', 'keywords': '', 'moddate': '2024-12-10T18:00:58+05:00', 'trapped': '', 'modDate': "D:20241210180058+05'00'", 'creationDate': "D:20241210180058+05'00'", 'page': 44}, page_content='• Start the backend server. In the backend directory, run:\n• Start the frontend server. In the frontend directory, run:\n• Navigate to http://localhost:3000 in your browser, and you should \nsee "Hello from the backend!" displayed, coming from your \nNode.js API.\nnode server.js\nnpm start\nStep 3: Start both servers\n41'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-10T18:00:58+05:00', 'source': '..\\data\\pdf\\Lecture 12.pdf', 'file_path': '..\\data\\pdf\\Lecture 12.pdf', 'total_pages': 55, 'format': 'PDF 1.7', 'title': '', 'author': 'Nida Rasheed', 'subject': '', 'keywords': '', 'moddate': '2024-12-10T18:00:58+05:00', 'trapped': '', 'modDate': "D:20241210180058+05'00'", 'creationDate': "D:20241210180058+05'00'", 'page': 45}, page_content='How the Communication Works\n• The frontend (React app) makes a GET request to the backend \nserver at http://localhost:5000/api/message.\n• The backend server (Express) listens for requests at this endpoint \nand responds with a JSON object containing a message.\n• Once the frontend receives the message, it updates the state and \ndisplays it in the h1 tag.\nThis is a basic client-server communication pattern where the \nfrontend fetches data from the backend and displays it dynamically.\n42'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-10T18:00:58+05:00', 'source': '..\\data\\pdf\\Lecture 12.pdf', 'file_path': '..\\data\\pdf\\Lecture 12.pdf', 'total_pages': 55, 'format': 'PDF 1.7', 'title': '', 'author': 'Nida Rasheed', 'subject': '', 'keywords': '', 'moddate': '2024-12-10T18:00:58+05:00', 'trapped': '', 'modDate': "D:20241210180058+05'00'", 'creationDate': "D:20241210180058+05'00'", 'page': 46}, page_content='Key Take-aways of the Example \n• Backend (Express): Defines routes, handles requests, sends \nresponses.\n• Frontend (React): Fetches data from the backend and updates \nthe UI based on the received data.\n• CORS: Allows communication between the frontend and backend \neven if they are running on different ports.\n43'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-10T18:00:58+05:00', 'source': '..\\data\\pdf\\Lecture 12.pdf', 'file_path': '..\\data\\pdf\\Lecture 12.pdf', 'total_pages': 55, 'format': 'PDF 1.7', 'title': '', 'author': 'Nida Rasheed', 'subject': '', 'keywords': '', 'moddate': '2024-12-10T18:00:58+05:00', 'trapped': '', 'modDate': "D:20241210180058+05'00'", 'creationDate': "D:20241210180058+05'00'", 'page': 47}, page_content='Differences \nbetween Node.js \nand the Browser\nBoth Browser and Node.js are environments for running JavaScript, but they are \ndesigned for different purposes and operate in distinct contexts.\n44'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-10T18:00:58+05:00', 'source': '..\\data\\pdf\\Lecture 12.pdf', 'file_path': '..\\data\\pdf\\Lecture 12.pdf', 'total_pages': 55, 'format': 'PDF 1.7', 'title': '', 'author': 'Nida Rasheed', 'subject': '', 'keywords': '', 'moddate': '2024-12-10T18:00:58+05:00', 'trapped': '', 'modDate': "D:20241210180058+05'00'", 'creationDate': "D:20241210180058+05'00'", 'page': 48}, page_content="Environment and Context\nBrowser\n• The browser is a client-side \nenvironment where JavaScript runs in \nthe user's web browser (like Chrome, \nFirefox, Safari, etc.).\n• Browsers are designed to render and \ninteract with web pages, handling \nthings like user interface (UI) updates, \nDOM manipulation, and \ncommunication with web servers via \nHTTP requests (using AJAX, Fetch, or \nWebSockets).\n• JavaScript in the browser can access \nand modify the Document Object \nModel (DOM), which represents the \nstructure of a web page.\nNode.js\n• Node.js is a server-side environment \nthat allows you to run JavaScript \noutside the browser, typically on a \nserver.\n• It provides a runtime for executing \nJavaScript for tasks like building server \napplications, interacting with \ndatabases, file systems, and more.\n• Node.js does not have access to the \nDOM or browser-specific features like \nHTML rendering but provides its own \nset of APIs for file system \nmanagement, networking, and other \nserver-side tasks.\n45"),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-10T18:00:58+05:00', 'source': '..\\data\\pdf\\Lecture 12.pdf', 'file_path': '..\\data\\pdf\\Lecture 12.pdf', 'total_pages': 55, 'format': 'PDF 1.7', 'title': '', 'author': 'Nida Rasheed', 'subject': '', 'keywords': '', 'moddate': '2024-12-10T18:00:58+05:00', 'trapped': '', 'modDate': "D:20241210180058+05'00'", 'creationDate': "D:20241210180058+05'00'", 'page': 49}, page_content='Purpose and Use Cases\nBrowser\n• Client-side operations: Browsers are \nused for tasks like rendering HTML \npages, styling with CSS, and \nhandling user input events (clicks, \nform submissions).\n• Interactivity on web pages: \nJavaScript in the browser can be \nused to create dynamic web pages \n(e.g., updating content without \nreloading, animations, etc.) using \nAPIs like DOM, CSSOM, and Web \nStorage.\nNode.js\n• Server-side operations: Node.js is \ncommonly used for building back-\nend applications, APIs, web \nservers, and handling networking \ntasks.\n• Non-blocking I/O: Node.js is known \nfor handling asynchronous \noperations, such as reading files, \nmaking HTTP requests, or querying \ndatabases without blocking the \nmain thread.\n46'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-10T18:00:58+05:00', 'source': '..\\data\\pdf\\Lecture 12.pdf', 'file_path': '..\\data\\pdf\\Lecture 12.pdf', 'total_pages': 55, 'format': 'PDF 1.7', 'title': '', 'author': 'Nida Rasheed', 'subject': '', 'keywords': '', 'moddate': '2024-12-10T18:00:58+05:00', 'trapped': '', 'modDate': "D:20241210180058+05'00'", 'creationDate': "D:20241210180058+05'00'", 'page': 50}, page_content='Purpose and Use Cases\nBrowser\nThe browser provides browser-specific APIs \nlike:\n• DOM (Document Object Model) for \nmanipulating web page structure.\n• Canvas API for drawing graphics and \nanimations.\n• Web Storage API (localStorage, \nsessionStorage) for saving data in the \nbrowser.\n• Geolocation API for getting the user’s \nlocation.\n• Fetch API for making HTTP requests to \nservers.\nThe browser environment focuses on web \npage rendering, user interaction, and \nsending data over HTTP.\nNode.js\nNode.js provides server-side APIs:\n• File System (fs) for reading, writing, and \nmanipulating files on the server.\n• http module to create web servers and \nhandle HTTP requests and responses.\n• path module for handling file and \ndirectory paths.\n• os module for getting information about \nthe operating system.\n• stream module for handling streaming \ndata.\nNode.js is designed for building scalable, \nnetworked applications, interacting with \ndatabases, file systems, and other \nservices.\n47'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-10T18:00:58+05:00', 'source': '..\\data\\pdf\\Lecture 12.pdf', 'file_path': '..\\data\\pdf\\Lecture 12.pdf', 'total_pages': 55, 'format': 'PDF 1.7', 'title': '', 'author': 'Nida Rasheed', 'subject': '', 'keywords': '', 'moddate': '2024-12-10T18:00:58+05:00', 'trapped': '', 'modDate': "D:20241210180058+05'00'", 'creationDate': "D:20241210180058+05'00'", 'page': 51}, page_content='Event Loop and Execution Model\nBrowser\n• Browsers also use an event-driven, \nnon-blocking I/O model, but their \nfocus is more on UI events (like \nclicks, keypresses, or mouse \nmovements) and DOM \nmanipulation.\n• JavaScript in the browser runs on a \nsingle thread, and the browser is \nresponsible for handling interactions \nwith the DOM, and other UI-related \ntasks.\nNode.js\n• Node.js runs on a single thread \nusing a non-blocking event-driven \nmodel. It uses an event loop to \nhandle asynchronous operations \n(e.g., database calls, file reads) \nefficiently without blocking the \nmain thread.\n• Node.js makes use of libuv, a C \nlibrary that provides the event loop \nand low-level I/O functionalities.\n48'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-10T18:00:58+05:00', 'source': '..\\data\\pdf\\Lecture 12.pdf', 'file_path': '..\\data\\pdf\\Lecture 12.pdf', 'total_pages': 55, 'format': 'PDF 1.7', 'title': '', 'author': 'Nida Rasheed', 'subject': '', 'keywords': '', 'moddate': '2024-12-10T18:00:58+05:00', 'trapped': '', 'modDate': "D:20241210180058+05'00'", 'creationDate': "D:20241210180058+05'00'", 'page': 52}, page_content="Event Loop and Execution Model\nBrowser\nIn the browser, the global object is \nwindow. It exposes methods like alert(), \nsetTimeout(), and document for \ninteracting with the DOM.\nOther browser-specific objects include:\n• document: For interacting with the \nHTML document.\n• localStorage/sessionStorage: For \nsaving data locally on the user's device.\n• navigator: For detecting the browser \nand device.\nNode.js\nIn Node.js, the global object is global. It \ndoes not have access to browser-\nspecific objects like window or \ndocument.\nNode.js exposes several useful global \nvariables, including:\n• __dirname: The directory name of the \ncurrent module.\n• __filename: The full filename of the \ncurrent module.\n• process: Provides information and \ncontrol over the Node.js process (e.g., \nexit, environment variables).\n• require: To import modules (both \nbuilt-in and custom).\n49"),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-10T18:00:58+05:00', 'source': '..\\data\\pdf\\Lecture 12.pdf', 'file_path': '..\\data\\pdf\\Lecture 12.pdf', 'total_pages': 55, 'format': 'PDF 1.7', 'title': '', 'author': 'Nida Rasheed', 'subject': '', 'keywords': '', 'moddate': '2024-12-10T18:00:58+05:00', 'trapped': '', 'modDate': "D:20241210180058+05'00'", 'creationDate': "D:20241210180058+05'00'", 'page': 53}, page_content='Summary of all differences\n• Browsers are designed for running JavaScript in the context of \ninteracting with web pages, DOM manipulation, and user \ninterfaces.\n• Node.js is designed to run JavaScript on the server side, providing \ntools for building APIs, handling file systems, networking, and \nmuch more.\n51'),
#  Document(metadata={'producer': 'Microsoft® PowerPoint® for Microsoft 365', 'creator': 'Microsoft® PowerPoint® for Microsoft 365', 'creationdate': '2024-12-10T18:00:58+05:00', 'source': '..\\data\\pdf\\Lecture 12.pdf', 'file_path': '..\\data\\pdf\\Lecture 12.pdf', 'total_pages': 55, 'format': 'PDF 1.7', 'title': '', 'author': 'Nida Rasheed', 'subject': '', 'keywords': '', 'moddate': '2024-12-10T18:00:58+05:00', 'trapped': '', 'modDate': "D:20241210180058+05'00'", 'creationDate': "D:20241210180058+05'00'", 'page': 54}, page_content='Useful Resources\n• https://nodejs.org/en/learn/getting-started/introduction-to-nodejs\n• https://www.w3schools.com/nodejs/nodejs_get_started.asp\n• https://www.w3schools.com/nodejs/nodejs_email.asp \n52')]

# %%
type(pdf[0])
# Out:
# langchain_core.documents.base.Document
